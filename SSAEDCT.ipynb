# %% [markdown]
# DATASET DOWNLOAD AND EXTRACT

# %%
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from utility import plot_confusion_matrix
import tensorflow.keras.layers as layer
from tensorflow.keras import Model
import matplotlib.pyplot as plt

# %%
seed = 1231829
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
from data_loader import get_data
X_data, labels = get_data()
# Out:
# /Users/denisderonjic/Repos/ActivityRecognition/data_loader.py:108: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return (np.array(X_data), labels)

# %%
print(X_data.shape)
print(labels.shape)
# Out:
# (761,)
# (761,)

# %%
import matplotlib.pyplot as plt

measure = 10
print(labels[measure])
accX = X_data[measure][:, 0]
#accX = np.fft.fft(accX)
plt.plot(accX, color='r')
plt.ylabel('Acc x')
plt.show()

accY = X_data[measure][:, 1]
#accY = np.fft.fft(accY)
plt.plot(accY, color='g')
plt.ylabel('Acc y')
plt.show()

accZ = X_data[measure][:, 2]
#accZ = np.fft.fft(accZ)
plt.plot(accZ, color='b')
plt.ylabel('Acc z')
plt.show()
del accX, accY, accZ
# Out:
# FALLING

# %%
from data_transformation import frame_data

X_data, y_data = frame_data(X_data, labels)

# %%
X_data = X_data[:,:, :6] #Dropping magnetometer

# %%
unique, counts = np.unique(y_data, return_counts=True)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(unique,counts)
plt.show()

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

y_data = le.fit_transform(y_data)

# %%
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(le_name_mapping)

num_labels = len(le_name_mapping)
print(num_labels)
# Out:
# {'FALLING': 0, 'JUMPING': 1, 'RUNNING': 2, 'SITTING': 3, 'STNDING': 4, 'WALKING': 5, 'XLYINGX': 6}
# 7

# %%
#import data_transformation as dt
#X_data, y_data = dt.data_augmentation(X_data, y_data, [dt.jitter])

# %%
from data_transformation import data_normalization
X_visual_norm = data_normalization(X_data[:20])
# Out:
# 2021-09-03 16:17:11.340792: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-09-03 16:17:11.340935: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
measure = 5
fig, axs = plt.subplots(3, 2)
fig.set_figheight(15)
fig.set_figwidth(15)
axs[0, 0].plot(X_data[measure,:,0], 'tab:red')
axs[0, 0].set_title('Real Acc x')
axs[0, 1].plot(X_visual_norm[measure,:,0], 'tab:red')
axs[0, 1].set_title('Norm Acc x')

axs[1, 0].plot(X_data[measure,:,1], 'tab:green')
axs[1, 0].set_title('Real Acc y')
axs[1, 1].plot(X_visual_norm[measure,:,1], 'tab:green')
axs[1, 1].set_title('Norm Acc y')

axs[2, 0].plot(X_data[measure,:,2], 'tab:blue')
axs[2, 0].set_title('Real Acc 1')
axs[2, 1].plot(X_visual_norm[measure,:,2], 'tab:blue')
axs[2, 1].set_title('Norm Acc 1')
# Out:
# Text(0.5, 1.0, 'Norm Acc 1')

# %%
X_data = np.fft.fft(X_data, axis=1).astype(np.float32)
# Out:
# /var/folders/yk/z_nrjlnn1l1d2pdf_3sly5k40000gn/T/ipykernel_6293/803724436.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   X_data = np.fft.fft(X_data, axis=1).astype(np.float32)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

stratifiedSplit = True

if stratifiedSplit:
    X_train = []
    X_test = []
    y_train = []
    y_test = []
    split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=seed)
    for train_index, test_index in split.split(X_data, y_data):
        X_train.append(X_data[train_index])
        y_train.append(y_data[train_index])
        X_test.append(X_data[test_index])
        y_test.append(y_data[test_index])
    X_train = np.array(X_train[0])
    y_train = np.array(y_train[0])
    X_test = np.array(X_test[0])
    y_test = np.array(y_test[0])
else:
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.3, random_state=seed)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (155666, 128, 6)
# (155666,)

# %%
measure = 5
fig, axs = plt.subplots(2, 3)
fig.set_figheight(15)
fig.set_figwidth(15)
axs[0, 0].plot(X_train[measure,:,0], 'tab:red')
axs[0, 0].set_title('Acc x')
axs[0, 1].plot(X_train[measure,:,1], 'tab:blue')
axs[0, 1].set_title('Acc y')
axs[0, 2].plot(X_train[measure,:,2], 'tab:green')
axs[0, 2].set_title('Acc z')

axs[1, 0].plot(X_train[measure,:,3], 'tab:red')
axs[1, 0].set_title('Gyro x')
axs[1, 1].plot(X_train[measure,:,4], 'tab:blue')
axs[1, 1].set_title('Gyro y')
axs[1, 2].plot(X_train[measure,:,5], 'tab:green')
axs[1, 2].set_title('Gyro z')
# Out:
# Text(0.5, 1.0, 'Gyro z')

# %%
from data_transformation import data_normalization
from data_transformation import min_max_scaler

#X_train = min_max_scaler(X_train)
#X_test = min_max_scaler(X_test)

X_train = data_normalization(X_train)
X_test = data_normalization(X_test)

# %%
print(X_train.shape)
# Out:
# (155666, 128, 6)

# %%
def plot_signal(signal):
    fig, axs = plt.subplots(2, 3)
    fig.set_figheight(15)
    fig.set_figwidth(15)
    axs[0, 0].plot(signal[:,0], 'tab:red')
    axs[0, 0].set_title('Acc x')
    axs[0, 1].plot(signal[:,1], 'tab:blue')
    axs[0, 1].set_title('Acc y')
    axs[0, 2].plot(signal[:,2], 'tab:green')
    axs[0, 2].set_title('Acc z')

    axs[1, 0].plot(signal[:,3], 'tab:red')
    axs[1, 0].set_title('Gyro x')
    axs[1, 1].plot(signal[:,4], 'tab:blue')
    axs[1, 1].set_title('Gyro y')
    axs[1, 2].plot(signal[:,5], 'tab:green')
    axs[1, 2].set_title('Gyro z')

# %%
measure = 5
print(le.inverse_transform([y_train[measure]])[0])
plot_signal(X_train[measure])
# Out:
# STNDING

# %%
encoded_space_dim = 64
signal_dimension = X_train.shape[-1]

encoder = tf.keras.models.Sequential(
        [
            layer.InputLayer(input_shape=(128, signal_dimension)),
            layer.Dropout(0.4),
            layer.Conv1D(filters=32, kernel_size=9, strides=2, activation='relu', padding='same'),
            layer.Conv1D(filters=64, kernel_size=7, strides=2, activation='relu', padding='same'),
            layer.Conv1D(filters=128, kernel_size=5, strides=2, activation='relu', padding='same'),
            layer.Conv1D(filters=256, kernel_size=3, strides=2, activation='relu', padding='same'),
            layer.Flatten(),
            layer.Dropout(rate=0.2),
            layer.Dense(encoded_space_dim),
        ], name="encoder"
    )

decoder = tf.keras.models.Sequential(
        [
            layer.InputLayer(input_shape=(encoded_space_dim)),
            layer.Dense(units=8*256, activation='relu'),
            layer.Reshape((8, 256)),
            layer.Conv1DTranspose(filters=128, kernel_size=5, strides=2, activation='relu', padding='same'),
            layer.Conv1DTranspose(filters=64, kernel_size=7, strides=2, activation='relu', padding='same'),
            layer.Conv1DTranspose(filters=32, kernel_size=9, strides=2, activation='relu', padding='same'),
            layer.Conv1DTranspose(filters=signal_dimension, kernel_size=3, strides=2, padding='same'),
        ], name="decoder"
    )

classifier = tf.keras.models.Sequential(
        [
            layer.Dense(512),
            layer.Dense(num_labels, activation='softmax'),
        ], name="classifier"
    )

# %%
from models import SSAE

autoencoder = SSAE(encoded_space_dim, encoder, decoder, classifier, alpha=0.1, beta=1.0)

autoencoder.predict(X_train[:10]).shape
autoencoder(X_train[:10]).shape
# Out:
# TensorShape([10, 128, 6])

# %%
autoencoder.summary()
# Out:
# Model: "ssae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Sequential)         (None, 64)                286944
# _________________________________________________________________
# decoder (Sequential)         (None, 128, 6)            262950
# _________________________________________________________________
# classifier (Sequential)      (10, 7)                   36871
# =================================================================
# Total params: 586,771
# Trainable params: 586,765
# Non-trainable params: 6
# _________________________________________________________________

# %%
autoencoder.encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 128, 6)            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 64, 32)            1760
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 32, 64)            14400
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 16, 128)           41088
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 8, 256)            98560
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                131136
# =================================================================
# Total params: 286,944
# Trainable params: 286,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 2048)              133120
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 256)            0
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 16, 128)           98432
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 32, 64)            24640
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 64, 32)            6176
# _________________________________________________________________
# conv1d_transpose_3 (Conv1DTr (None, 128, 6)            582
# =================================================================
# Total params: 262,950
# Trainable params: 262,950
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.classifier.summary()
# Out:
# Model: "classifier"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (10, 512)                 33280
# _________________________________________________________________
# dense_3 (Dense)              (10, 7)                   3591
# =================================================================
# Total params: 36,871
# Trainable params: 36,871
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam()

autoencoder.compile(optimizer=optimizer)

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
history = autoencoder.fit(X_train, y_train,
                epochs=100,
                shuffle=True,
                batch_size=128,
                validation_split=0.2,
                callbacks=[callback]
                )
# Out:
# Epoch 1/100
# 973/973 [==============================] - 25s 25ms/step - loss: 11.6218 - rec_loss: 99.0652 - pred_loss: 0.7330 - val_loss: 9.0558 - val_rec_loss: 84.1449 - val_pred_loss: 0.6413
# Epoch 2/100
# 973/973 [==============================] - 25s 26ms/step - loss: 8.6576 - rec_loss: 77.6391 - pred_loss: 0.6038 - val_loss: 7.8024 - val_rec_loss: 72.3125 - val_pred_loss: 0.5712
# Epoch 3/100
# 973/973 [==============================] - 27s 28ms/step - loss: 7.5708 - rec_loss: 68.7841 - pred_loss: 0.5555 - val_loss: 7.1142 - val_rec_loss: 65.7634 - val_pred_loss: 0.5378
# Epoch 4/100
# 973/973 [==============================] - 26s 27ms/step - loss: 7.0756 - rec_loss: 63.7674 - pred_loss: 0.5115 - val_loss: 6.6969 - val_rec_loss: 61.8724 - val_pred_loss: 0.5096
# Epoch 5/100
# 973/973 [==============================] - 26s 27ms/step - loss: 6.4488 - rec_loss: 59.7509 - pred_loss: 0.4802 - val_loss: 6.2640 - val_rec_loss: 57.7551 - val_pred_loss: 0.4885
# Epoch 6/100
# 973/973 [==============================] - 26s 27ms/step - loss: 6.1278 - rec_loss: 56.0167 - pred_loss: 0.4584 - val_loss: 5.9031 - val_rec_loss: 54.1448 - val_pred_loss: 0.4886
# Epoch 7/100
# 973/973 [==============================] - 26s 27ms/step - loss: 5.7882 - rec_loss: 52.4629 - pred_loss: 0.4364 - val_loss: 5.6256 - val_rec_loss: 51.6813 - val_pred_loss: 0.4575
# Epoch 8/100
# 973/973 [==============================] - 27s 27ms/step - loss: 5.4177 - rec_loss: 49.5286 - pred_loss: 0.4230 - val_loss: 5.2884 - val_rec_loss: 48.3663 - val_pred_loss: 0.4517
# Epoch 9/100
# 973/973 [==============================] - 25s 26ms/step - loss: 5.1625 - rec_loss: 46.7225 - pred_loss: 0.4127 - val_loss: 5.0311 - val_rec_loss: 45.8614 - val_pred_loss: 0.4450
# Epoch 10/100
# 973/973 [==============================] - 25s 26ms/step - loss: 4.8240 - rec_loss: 43.9614 - pred_loss: 0.4021 - val_loss: 4.7222 - val_rec_loss: 42.7960 - val_pred_loss: 0.4425
# Epoch 11/100
# 973/973 [==============================] - 26s 26ms/step - loss: 4.5650 - rec_loss: 41.0902 - pred_loss: 0.3933 - val_loss: 4.3970 - val_rec_loss: 39.6668 - val_pred_loss: 0.4303
# Epoch 12/100
# 973/973 [==============================] - 26s 26ms/step - loss: 4.2957 - rec_loss: 38.7341 - pred_loss: 0.3805 - val_loss: 4.2073 - val_rec_loss: 37.8312 - val_pred_loss: 0.4242
# Epoch 13/100
# 973/973 [==============================] - 24s 25ms/step - loss: 4.0993 - rec_loss: 37.0339 - pred_loss: 0.3703 - val_loss: 4.0650 - val_rec_loss: 36.3055 - val_pred_loss: 0.4344
# Epoch 14/100
# 973/973 [==============================] - 24s 25ms/step - loss: 3.9249 - rec_loss: 35.4575 - pred_loss: 0.3610 - val_loss: 3.9472 - val_rec_loss: 35.1257 - val_pred_loss: 0.4346
# Epoch 15/100
# 973/973 [==============================] - 24s 25ms/step - loss: 3.7631 - rec_loss: 33.8460 - pred_loss: 0.3511 - val_loss: 3.7467 - val_rec_loss: 33.2009 - val_pred_loss: 0.4267
# Epoch 16/100
# 973/973 [==============================] - 24s 24ms/step - loss: 3.6383 - rec_loss: 32.6211 - pred_loss: 0.3435 - val_loss: 3.7418 - val_rec_loss: 33.1412 - val_pred_loss: 0.4276
# Epoch 17/100
# 973/973 [==============================] - 25s 26ms/step - loss: 3.5268 - rec_loss: 31.7969 - pred_loss: 0.3303 - val_loss: 3.6011 - val_rec_loss: 31.6243 - val_pred_loss: 0.4386
# Epoch 18/100
# 973/973 [==============================] - 25s 25ms/step - loss: 3.4255 - rec_loss: 31.1187 - pred_loss: 0.3218 - val_loss: 3.5738 - val_rec_loss: 31.6038 - val_pred_loss: 0.4134
# Epoch 19/100
# 973/973 [==============================] - 24s 25ms/step - loss: 3.3743 - rec_loss: 30.5771 - pred_loss: 0.3123 - val_loss: 3.4806 - val_rec_loss: 30.6322 - val_pred_loss: 0.4174
# Epoch 20/100
# 973/973 [==============================] - 24s 24ms/step - loss: 3.2890 - rec_loss: 30.0166 - pred_loss: 0.3043 - val_loss: 3.3857 - val_rec_loss: 29.7610 - val_pred_loss: 0.4096
# Epoch 21/100
# 973/973 [==============================] - 25s 25ms/step - loss: 3.2023 - rec_loss: 29.2261 - pred_loss: 0.2939 - val_loss: 3.3351 - val_rec_loss: 29.1253 - val_pred_loss: 0.4226
# Epoch 22/100
# 973/973 [==============================] - 25s 25ms/step - loss: 3.1080 - rec_loss: 28.7363 - pred_loss: 0.2880 - val_loss: 3.2895 - val_rec_loss: 28.7365 - val_pred_loss: 0.4159
# Epoch 23/100
# 973/973 [==============================] - 26s 26ms/step - loss: 3.1437 - rec_loss: 28.4034 - pred_loss: 0.2779 - val_loss: 3.2668 - val_rec_loss: 28.3344 - val_pred_loss: 0.4334
# Epoch 24/100
# 973/973 [==============================] - 26s 27ms/step - loss: 3.0749 - rec_loss: 28.2115 - pred_loss: 0.2700 - val_loss: 3.2651 - val_rec_loss: 28.4447 - val_pred_loss: 0.4206
# Epoch 25/100
# 973/973 [==============================] - 27s 28ms/step - loss: 3.0612 - rec_loss: 27.9679 - pred_loss: 0.2660 - val_loss: 3.2509 - val_rec_loss: 28.2694 - val_pred_loss: 0.4240
# Epoch 26/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.9846 - rec_loss: 27.6917 - pred_loss: 0.2562 - val_loss: 3.2504 - val_rec_loss: 27.9536 - val_pred_loss: 0.4551
# Epoch 27/100
# 973/973 [==============================] - 26s 27ms/step - loss: 3.0425 - rec_loss: 27.4570 - pred_loss: 0.2535 - val_loss: 3.1692 - val_rec_loss: 27.4182 - val_pred_loss: 0.4274
# Epoch 28/100
# 973/973 [==============================] - 27s 28ms/step - loss: 3.0039 - rec_loss: 27.2645 - pred_loss: 0.2451 - val_loss: 3.1659 - val_rec_loss: 27.1203 - val_pred_loss: 0.4539
# Epoch 29/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.8247 - rec_loss: 26.8995 - pred_loss: 0.2400 - val_loss: 3.1770 - val_rec_loss: 27.0523 - val_pred_loss: 0.4718
# Epoch 30/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.9070 - rec_loss: 26.5982 - pred_loss: 0.2350 - val_loss: 3.0904 - val_rec_loss: 26.5925 - val_pred_loss: 0.4311
# Epoch 31/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.8512 - rec_loss: 26.3605 - pred_loss: 0.2300 - val_loss: 3.1452 - val_rec_loss: 26.7427 - val_pred_loss: 0.4709
# Epoch 32/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.8475 - rec_loss: 26.1085 - pred_loss: 0.2230 - val_loss: 3.0775 - val_rec_loss: 26.3306 - val_pred_loss: 0.4445
# Epoch 33/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.8544 - rec_loss: 26.0819 - pred_loss: 0.2227 - val_loss: 3.0741 - val_rec_loss: 26.0505 - val_pred_loss: 0.4691
# Epoch 34/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.7866 - rec_loss: 25.7757 - pred_loss: 0.2149 - val_loss: 3.0967 - val_rec_loss: 26.2221 - val_pred_loss: 0.4745
# Epoch 35/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.7923 - rec_loss: 25.7238 - pred_loss: 0.2119 - val_loss: 3.0269 - val_rec_loss: 25.7944 - val_pred_loss: 0.4474
# Epoch 36/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.7099 - rec_loss: 25.3111 - pred_loss: 0.2056 - val_loss: 2.9861 - val_rec_loss: 25.2006 - val_pred_loss: 0.4661
# Epoch 37/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.7144 - rec_loss: 25.0960 - pred_loss: 0.2005 - val_loss: 2.9807 - val_rec_loss: 25.0715 - val_pred_loss: 0.4736
# Epoch 38/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.6828 - rec_loss: 24.7798 - pred_loss: 0.1986 - val_loss: 2.9841 - val_rec_loss: 24.5073 - val_pred_loss: 0.5333
# Epoch 39/100
# 973/973 [==============================] - 26s 26ms/step - loss: 2.6490 - rec_loss: 24.3784 - pred_loss: 0.1913 - val_loss: 2.9603 - val_rec_loss: 24.8420 - val_pred_loss: 0.4761
# Epoch 40/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.6164 - rec_loss: 24.3097 - pred_loss: 0.1934 - val_loss: 2.9501 - val_rec_loss: 24.4763 - val_pred_loss: 0.5025
# Epoch 41/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.5665 - rec_loss: 24.0135 - pred_loss: 0.1876 - val_loss: 2.9246 - val_rec_loss: 24.3159 - val_pred_loss: 0.4931
# Epoch 42/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.5339 - rec_loss: 23.8435 - pred_loss: 0.1835 - val_loss: 3.2167 - val_rec_loss: 27.1484 - val_pred_loss: 0.5019
# Epoch 43/100
# 973/973 [==============================] - 28s 29ms/step - loss: 2.5621 - rec_loss: 23.8071 - pred_loss: 0.1826 - val_loss: 3.0790 - val_rec_loss: 25.4310 - val_pred_loss: 0.5359
# Epoch 44/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.5785 - rec_loss: 23.6873 - pred_loss: 0.1761 - val_loss: 2.8608 - val_rec_loss: 23.5223 - val_pred_loss: 0.5086
# Epoch 45/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.4865 - rec_loss: 23.5520 - pred_loss: 0.1703 - val_loss: 2.9417 - val_rec_loss: 23.8802 - val_pred_loss: 0.5537
# Epoch 46/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.5197 - rec_loss: 23.5542 - pred_loss: 0.1734 - val_loss: 2.9343 - val_rec_loss: 24.1940 - val_pred_loss: 0.5149
# Epoch 47/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.4974 - rec_loss: 23.2777 - pred_loss: 0.1686 - val_loss: 3.0437 - val_rec_loss: 24.9400 - val_pred_loss: 0.5497
# Epoch 48/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.4668 - rec_loss: 23.0623 - pred_loss: 0.1651 - val_loss: 2.8688 - val_rec_loss: 23.4227 - val_pred_loss: 0.5266
# Epoch 49/100
# 973/973 [==============================] - 27s 27ms/step - loss: 2.4501 - rec_loss: 23.0363 - pred_loss: 0.1624 - val_loss: 2.8394 - val_rec_loss: 23.1737 - val_pred_loss: 0.5220
# Epoch 50/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.3899 - rec_loss: 23.0500 - pred_loss: 0.1598 - val_loss: 2.8736 - val_rec_loss: 23.3423 - val_pred_loss: 0.5393
# Epoch 51/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.4318 - rec_loss: 22.8847 - pred_loss: 0.1592 - val_loss: 2.8273 - val_rec_loss: 23.0167 - val_pred_loss: 0.5257
# Epoch 52/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.3876 - rec_loss: 22.9065 - pred_loss: 0.1584 - val_loss: 2.8856 - val_rec_loss: 23.2364 - val_pred_loss: 0.5619
# Epoch 53/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.4047 - rec_loss: 22.6369 - pred_loss: 0.1501 - val_loss: 2.8251 - val_rec_loss: 22.8535 - val_pred_loss: 0.5398
# Epoch 54/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.3796 - rec_loss: 22.5100 - pred_loss: 0.1456 - val_loss: 2.9252 - val_rec_loss: 23.5977 - val_pred_loss: 0.5655
# Epoch 55/100
# 973/973 [==============================] - 28s 29ms/step - loss: 2.3977 - rec_loss: 22.3829 - pred_loss: 0.1496 - val_loss: 2.8564 - val_rec_loss: 22.6902 - val_pred_loss: 0.5873
# Epoch 56/100
# 973/973 [==============================] - 28s 29ms/step - loss: 2.4189 - rec_loss: 22.1577 - pred_loss: 0.1403 - val_loss: 2.7560 - val_rec_loss: 21.9998 - val_pred_loss: 0.5560
# Epoch 57/100
# 973/973 [==============================] - 27s 28ms/step - loss: 2.3336 - rec_loss: 22.0067 - pred_loss: 0.1484 - val_loss: 2.8064 - val_rec_loss: 22.2876 - val_pred_loss: 0.5777
# Epoch 58/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.3089 - rec_loss: 21.9172 - pred_loss: 0.1436 - val_loss: 2.7796 - val_rec_loss: 22.1694 - val_pred_loss: 0.5627
# Epoch 59/100
# 973/973 [==============================] - 26s 27ms/step - loss: 2.3038 - rec_loss: 21.8268 - pred_loss: 0.1342 - val_loss: 2.7747 - val_rec_loss: 21.9982 - val_pred_loss: 0.5749
# Epoch 60/100
# 973/973 [==============================] - 25s 26ms/step - loss: 2.3363 - rec_loss: 21.8005 - pred_loss: 0.1402 - val_loss: 2.7782 - val_rec_loss: 22.1217 - val_pred_loss: 0.5661
# Epoch 61/100
# 973/973 [==============================] - 25s 26ms/step - loss: 2.3031 - rec_loss: 21.6963 - pred_loss: 0.1305 - val_loss: 2.7788 - val_rec_loss: 21.9039 - val_pred_loss: 0.5884

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
X_trans = autoencoder(X_train[:1000])

# %%
measure = 24
label_measured = y_train[measure]
print(le.inverse_transform([label_measured])[0])
fig, axs = plt.subplots(3, 2)
fig.set_figheight(15)
fig.set_figwidth(15)
axs[0, 0].plot(X_train[measure,:,0], 'tab:red')
axs[0, 0].set_title('Real Acc x')
axs[0, 1].plot(X_trans[measure,:,0], 'tab:red')
axs[0, 1].set_title('Pred Acc x')

axs[1, 0].plot(X_train[measure,:,1], 'tab:green')
axs[1, 0].set_title('Real Acc y')
axs[1, 1].plot(X_trans[measure,:,1], 'tab:green')
axs[1, 1].set_title('Pred Acc y')

axs[2, 0].plot(X_train[measure,:,2], 'tab:blue')
axs[2, 0].set_title('Real Acc 1')
axs[2, 1].plot(X_trans[measure,:,2], 'tab:blue')
axs[2, 1].set_title('Pred Acc 1')
# Out:
# WALKING
# Text(0.5, 1.0, 'Pred Acc 1')

# %%
### Get the encoded representation of the test samples
test_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(10000).batch(1000)
encoded_samples = []
labels = []
for sample, label in test_dataset:
    output = autoencoder.encode(sample)
    
    # Append to list
    encoded = output.numpy()
    for i in range(len(encoded)):
      enc = encoded[i]
      lbl = label[i]
      encoded_samples.append(enc)
      labels.append(lbl)
    if len(encoded_samples) % 10000 == 0:
      break
labels = np.array(labels)

# %%
print(np.array(encoded_samples).shape)
# Out:
# (10000, 64)

# %%
from sklearn import manifold
tsne = manifold.TSNE(2, init='pca', random_state=0).fit_transform(encoded_samples)

# %%
labels = le.inverse_transform(labels)

# %%
import plotly.express as px
px.scatter(x=tsne[:,0], y=tsne[:,1], color=labels, opacity=0.7)

# %%
y_pred = autoencoder.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_pred, y_test)

# %%
np.trace(conf_mat) / np.sum(conf_mat)
# Out:
# 0.8546803567413626

# %%
from sklearn.metrics import precision_score, recall_score

#None, 'micro', 'macro', 'weighted'
precisions = precision_score(y_test, y_pred, average=None)
recalls = recall_score(y_test, y_pred, average=None)
print("Precision score: ", precisions)
print("Recall score: ", recalls)
# Out:
# Precision score:  [0.67320261 0.62680618 0.91080921 0.79595186 0.86518082 0.96917073
#  0.67378388]
# Recall score:  [0.48018648 0.75329341 0.92640433 0.78243835 0.89561185 0.95281028
#  0.59443079]

# %%
for i in range(num_labels):
    print(le.inverse_transform([i])[0]+": Precision " + str(precisions[i]) + " Recall " + str(recalls[i]))
# Out:
# FALLING: Precision 0.673202614379085 Recall 0.4801864801864802
# JUMPING: Precision 0.6268061783756851 Recall 0.7532934131736527
# RUNNING: Precision 0.9108092144122859 Recall 0.9264043256233103
# SITTING: Precision 0.7959518599562363 Recall 0.7824383498501959
# STNDING: Precision 0.8651808150333224 Recall 0.8956118525220539
# WALKING: Precision 0.969170731707317 Recall 0.9528102819873393
# XLYINGX: Precision 0.6737838841440772 Recall 0.5944307944307944

# %%
from sklearn.metrics import f1_score

f1_scores = f1_score(y_test, y_pred, average=None)
for i in range(num_labels):
    print(le.inverse_transform([i])[0]+": F1-score " + str(f1_scores[i]))
# Out:
# FALLING: F1-score 0.5605442176870749
# JUMPING: F1-score 0.6842534675006798
# RUNNING: F1-score 0.9185405807892777
# SITTING: F1-score 0.7891372564211832
# STNDING: F1-score 0.8801333703806614
# WALKING: F1-score 0.9609208744437996
# XLYINGX: F1-score 0.6316247498041946

# %%
import matplotlib.cm

def plot_confusion_matrix(predictions, labels, target_names):

  '''
  ============================
  Internal function definition
  ============================
  '''
  def _confusion_matrix(cm,
                            target_names,
                            title='Confusion matrix',
                            cmap=None):
      import itertools

      accuracy = np.trace(cm) / float(np.sum(cm))
      misclass = 1 - accuracy

      if cmap is None:
          cmap = plt.get_cmap('Reds')
      
      cm = cm.astype('float')
      for i in range(len(cm)):
        cm[i] /= float(np.sum(cm[i]))

      plt.figure(figsize=(16, 12))
      plt.imshow(cm, interpolation='nearest', cmap=cmap)
      plt.title(title)
      plt.colorbar()

      if target_names is not None:
          tick_marks = np.arange(len(target_names))
          plt.xticks(tick_marks, target_names, rotation=45)
          plt.yticks(tick_marks, target_names)


      thresh = cm.max() / 2
      for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                      horizontalalignment="center",
                      color="white" if cm[i, j] > thresh else "black")
              


      plt.tight_layout()
      plt.ylabel('True label')
      plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
      plt.show()
  '''
  ===================================
  End of internal function definition
  ===================================
  '''

  from sklearn.metrics import confusion_matrix

  conf_mat = confusion_matrix(predictions, labels)
  _confusion_matrix(conf_mat, target_names=target_names)

# %%
plot_confusion_matrix(y_pred, y_test, target_names=le.classes_)

# %%
autoencoder.save_model("best_SSAE_model_DCT")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
